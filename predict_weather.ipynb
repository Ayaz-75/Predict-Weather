# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('Tempreture_1901_2016_Pakistan.csv')
df = data.copy()
df.head()
# Out:
#    Temperature - (Celsius)   Year     Month
# 0                  7.72768   1901   January
# 1                  8.93600   1901  February
# 2                 16.96320   1901     March
# 3                 21.27410   1901     April
# 4                 26.04970   1901       May

# %%
df.describe()
# Out:
#        Temperature - (Celsius)         Year
# count              1392.000000  1392.000000
# mean                 20.007129  1958.500000
# std                   7.377193    33.497105
# min                   5.913480  1901.000000
# 25%                  13.119875  1929.750000
# 50%                  21.170700  1958.500000
# 75%                  27.211500  1987.250000
# max                  30.305800  2016.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of       Temperature - (Celsius)   Year      Month
# 0                     7.72768   1901    January
# 1                     8.93600   1901   February
# 2                    16.96320   1901      March
# 3                    21.27410   1901      April
# 4                    26.04970   1901        May
# ...                       ...    ...        ...
# 1387                 27.63320   2016     August
# 1388                 26.71790   2016  September
# 1389                 22.39820   2016    October
# 1390                 15.76720   2016   November
# 1391                 12.87630   2016   December
#
# [1392 rows x 3 columns]>

# %%
# df.isna().sum()
df.columns
# Out:
# Index(['Temperature - (Celsius)', ' Year', 'Month'], dtype='object')

# %%
sns.set(rc={'figure.figsize':(12,7)})
sns.lineplot(data=df, x=df['Month'], y=df['Temperature - (Celsius)']).set_title('Temprature on each month in Pakistan');

# %%
sns.set(rc={'figure.figsize':(12,7)})
sns.barplot(df['Month'], y=df['Temperature - (Celsius)']).set_title('Temprature on each month in Pakistan');
# Out:
# C:\Users\Ayaz Lakho\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(data=df, x=df[' Year'], y=df['Temperature - (Celsius)'])
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = df[' Year']
y = df['Temperature - (Celsius)']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=0)

# %%
regr = LinearRegression()
regr.fit(x.values.reshape(-1,1), y)
# Out:
# LinearRegression()

# %%
regr.coef_
# Out:
# array([0.00763535])

# %%
regr.intercept_
# Out:
# 5.053295439466165

# %%
predictions = regr.predict(x_test.values.reshape(-1,1))
print(len(predictions))
# Out:
# 460

# %%
sns.set(rc={'figure.figsize':(8,5)})

sns.histplot(predictions).set_title('Histogram plot for predicted data')
# Out:
# Text(0.5, 1.0, 'Histogram plot for predicted data')
